# %%
### 0. Load Required Packages and Utility Functions
defaultW = getOption("warn") 
options(warn = -1) 
options(scipen = 10000)
suppressPackageStartupMessages({
    library(rstan)
    options(mc.cores = parallel::detectCores())
    rstan_options(auto_write = TRUE)
    Sys.setenv(LOCAL_CPPFLAGS = '-march=native')

    library(brms)
    library(lme4)
    library(here)
    library(tidyverse)
    library(tidybayes)
    library(bayesplot)
    library(lubridate)
    library(zoo)
    library(foreach)
    library(doParallel)
    library(doSNOW)
})

source("Packages/Utility_Functions_MMM.R")
source('Optimization_functions/common_functions_mmm.R')
source('Optimization_functions/compute_elasticity_&_contribution.r')
source('Optimization_functions/extract_media_params_for_optimization.R')
source('Optimization_functions/plot_model_metrics.R')

# %%
#load('model_fits/fit_PP_44_10_C1.RData')
load("RData/data_XyZ_ts_comp.RData")
load("RData/pp_MMM_ts_comp_xy995.RData")

# %%
target_cols            = c('gross_add_true')
media_spend_cols             = c("radio_spend","tv_spend","print_spend","dm_spend","audio_spend",
                      "display_spend","video_spend","paid_search_spend_brand", 
                      "paid_search_spend_unbranded","social_spend")

target_norm_cols_vec = c('non_sub')
nbr_period_q <- 13

# %%
data_XyZ <- get_quarters(data_XyZ_ts_comp)
# Out:
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.

# %%
mean_qy_spend <- data_XyZ %>%
                    select(qy,dma,media_spend_cols) %>%
                    group_by(qy,dma) %>%
                    summarize_at(.vars = vars(media_spend_cols),.funs = sum) %>%
                    group_by(dma) %>%
                    summarize_at(.vars = vars(media_spend_cols),.funs = mean) %>%
                    #mutate_at(.vars = vars(media_spend_cols),.funs = ~./nbr_period_q) %>%
                    as.data.frame()
mean_qy_spend
# Out:
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(media_spend_cols)` instead of `media_spend_cols` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#    dma                            radio_spend tv_spend   print_spend dm_spend
# 1  ABILENE-SWEETWATER TX           14175.550   106546.19   6205.3542   76923.47
# 2  ALEXANDRIA LA                   16637.793   124594.70   3825.2124   85704.23
# 3  All Other Suddenlink DMA Total 145773.334   258618.40  16641.8546  326039.34
# 4  AMARILLO TX                     25603.713   147992.09  18240.0636  158723.01
# 5  AUSTIN TX                       75379.090        0.00  13526.7744  107789.71
# 6  BLUEFIELD-BECKLEY-OAK HILL WV   27548.527   103823.96   1678.5735   77789.80
# 7  CHARLESTON-HUNTINGTON WV        28192.823   164182.08   4815.9718  154027.96
# 8  DALLAS-FT WORTH TX              96678.177        0.00  31890.2384  274569.17
# 9  EUREKA CA                       12527.670    93607.90   1565.7424   49734.69
# 10 GREENVILLE-NEW BERN-WASH NC     26747.920   139132.86   5572.0717  151479.61
# 11 HOUSTON TX                     152341.837        0.00  28412.1639  192170.91
# 12 JONESBORO AR                    18157.007   139512.40   4820.5136   45214.68
# 13 LAKE CHARLES LA                 22897.925   163021.62   7334.1551   79200.95
# 14 LITTLE ROCK AR                  31271.761   129854.99   6226.9615  136674.59
# 15 LUBBOCK TX                      26824.137   136593.78  15843.4193  178933.67
# 16 MONROE-EL DORADO LA-AR           9947.137    91921.22   1974.8485   66532.15
# 17 NEW YORK, NY                   964101.362  9542487.90 129741.5150 4870237.82
# 20 4.466667    13.00000      12.93333    13.00000
# 21 5.200000    13.00000      13.00000    13.00000
# 22 5.066667    13.00000      13.00000    13.00000
# 23 4.466667    13.00000      12.86667    13.00000
# 24 4.666667    13.00000      12.93333    13.00000
# 25 5.066667    13.00000      12.93333    13.00000
# 26 4.400000    13.00000      12.93333    13.00000
# 27 4.600000    12.93333      12.80000    13.00000
# 28 4.666667    13.00000      13.00000    13.00000
# 29 4.400000    12.93333      12.86667    13.00000
# 30 4.600000    13.00000      13.00000    13.00000
#    paid_search_spend_unbranded social_spend
# 1  12.93333                    12.80000
# 2  13.00000                    12.86667
# 3  13.00000                    13.00000
# 4  12.93333                    12.93333
# 5  13.00000                    12.93333
# 6  13.00000                    13.00000
# 7  13.00000                    12.93333
# 8  13.00000                    13.00000
# 9  12.80000                    12.93333
# 10 13.00000                    12.66667
# 11 13.00000                    12.86667
# 12 12.86667                    12.80000
# 13 13.00000                    12.86667
# 14 12.93333                    12.93333
# 15 13.00000                    12.80000
# 16 12.93333                    12.80000
# 17 13.00000                    13.00000
# 18 12.93333                    12.73333
# 19 13.00000                    12.66667
# 20 13.00000                    12.80000
# 21 13.00000                    12.80000
# 22 13.00000                    12.66667
# 23 13.00000                    12.73333
# 24 13.00000                    12.60000
# 25 13.00000                    12.93333
# 26 12.93333                    12.80000
# 27 13.00000                    12.86667
# 28 13.00000                    12.80000
# 29 13.00000                    12.80000
# 30 13.00000                    12.73333

# %% [markdown]
# ## PP_44_10_C18_xy995

# %%
load('Optimization_results/Optimizer_PP_44_10_C18_xy995.RData')

# %%
load('MCMC_objs/MCMC_objs_EVA_PP_44_10_C18_xy995.rda')

# %%
MCMC_beta_media <- MCMC_objs$beta_media
MCMC_beta_base_control <- MCMC_objs$beta_base_control
MCMC_alpha_K_S <- MCMC_objs$alpha_K_S
fit_metrics_df <- MCMC_objs$eval_metrics

# %%
## Naming the model results with the corresponding actual target name
## Get the geo dfs list
names_geo_df           = ls(pattern='*44_10_C18.*geo_para')
res_geo_df_list        = c()
res_geo_df_list        <- lapply(names_geo_df,FUN = function(x){append(res_geo_df_list,setNames(list(as.data.frame(get(x))),x),0)})
names(res_geo_df_list) = target_cols

## Get the population dfs list
names_pop_df           = ls(pattern='*44_10_C18.*pop_para')
res_pop_df_list        = c()
res_pop_df_list        <- lapply(names_pop_df,FUN = function(x){append(res_pop_df_list,setNames(list(as.data.frame(get(x))),x),0)})
names(res_pop_df_list) = target_cols
target_norm_cols <- 'non_sub'

# %%
names_geo_df
names_pop_df
# Out:
# [1] "PP_44_10_C18_xy995_geo_para_stat"
# [1] "PP_44_10_C18_xy995_pop_para_stat"

# %%
test_extraction <- make_optim_data_mmm(data_XyZ              = data_XyZ,
                                               list_pop_param_df     = res_pop_df_list,
                                               list_geo_param_df     = res_geo_df_list,
                                               target_names_vec      = target_cols,
                                               list_preprocessed_data= pp_MMM_ts_comp_xy995,
                                               media_norm_type       = 4,
                                               target_norm_type      = 4,
                                               pooling_type = 'partial',
                                               target_norm_cols = target_norm_cols
                                               )
# Out:
# DMA names:
# 1 ABILENE-SWEETWATER TX
# 2 ALEXANDRIA LA
# 3 All Other Suddenlink DMA Total
# 4 AMARILLO TX
# 5 AUSTIN TX
# 6 BLUEFIELD-BECKLEY-OAK HILL WV
# 7 CHARLESTON-HUNTINGTON WV
# 8 DALLAS-FT WORTH TX
# 9 EUREKA CA
# 10 GREENVILLE-NEW BERN-WASH NC
# 11 HOUSTON TX
# 12 JONESBORO AR
# 13 LAKE CHARLES LA
# 14 LITTLE ROCK AR
# 15 LUBBOCK TX
# 16 MONROE-EL DORADO LA-AR
# 17 NEW YORK, NY
# 18 ODESSA-MIDLAND TX
# 19 OKLAHOMA CITY OK
# 20 PARKERSBURG WV
# 21 PHOENIX AZ
# 22 RALEIGH-DURHAM NC
# 23 SAN ANGELO TX
# 24 SHREVEPORT LA
# 25 SPRINGFIELD MO
# 26 ST JOSEPH MO
# 27 TULSA OK
# 28 TYLER-LONGVIEW TX
# 29 VICTORIA TX
# 30 WACO-TEMPLE-BRYAN TX
# media names:
# 1 tv_spend
# 2 dm_spend
# 3 paid_search_spend_brand
# 4 paid_search_spend_unbranded
# 5 display_spend
# 6 radio_spend
# 7 video_spend
# 8 print_spend
# 9 social_spend
# 10 audio_spend
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(final_data_cols)` instead of `final_data_cols` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# Adding missing grouping variables: `dma_id`, `dma`, `X`
#
# Adding missing grouping variables: `dma_id`, `dma`, `X`
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(control_names_vec)` instead of `control_names_vec` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.

# %%
# Outputs from `make_optim_data_mmm`
spend_cols_vec    = test_extraction$gross_add_true$media$spend_cols_vec
media_names_vec   = test_extraction$gross_add_true$media$media_names_vec
dma_names_vec     = test_extraction$gross_add_true$other$dma_names_vec
common_params_df  = test_extraction$gross_add_true$media$common_params_df
beta_media_mat    = test_extraction$gross_add_true$media$beta_media_mat
beta_control_mat  = test_extraction$gross_add_true$control$beta_control_mat
min_media_mat     = test_extraction$gross_add_true$media$min_media_mat
max_media_mat     = test_extraction$gross_add_true$media$max_media_mat
prospect_df       = test_extraction$gross_add_true$other$prospect_df
control_names_vec = test_extraction$gross_add_true$control$control_names_vec
control_mat       = test_extraction$gross_add_true$control$control_matrix
target_max_vec    = test_extraction$gross_add_true$target$target_max_vec
subs_col          = test_extraction$gross_add_true$other$subs_col
cleaned_names_list = test_extraction$gross_add_true$media$cleaned_media_names_vec
target_capita_norm_col = test_extraction$gross_add_true$target$target_capita_norm_col

# %%
prospect_vec = prospect_df[['non_sub']]
prospect_mat_media = matrix(prospect_vec,nrow = length(dma_names_vec), ncol = length(media_names_vec))

# %%
#*************  Simulator for Optimization  ***************************

###################################################################################################################################
#Global parameters needed for optimization
###################################################################################################################################
##Vector of Optimum DMA
optimum_dma =  c('NEW YORK, NY')
non_tv_dmas = mean_weekly_spend %>%
                mutate(dma_id = row_number(dma)) %>%
                filter(tv_spend == 0) %>%
                select(dma_id) %>%
                pull()


# media_names_vec = c('cross_channel','DM','outbound_call')


##Spend to activity ratio dataframe by DMA and media. Used primarily for activity based models for converting the activity to spend for optimization_ Dim - ndma*nmedia
spend_activity_ratio_dma_df <- as.data.frame(matrix(1, length(dma_names_vec), length(media_names_vec)))
colnames(spend_activity_ratio_dma_df) <- media_names_vec
spend_activity_ratio_dma_df[non_tv_dmas,'tv'] <- 0 

##Shape parameters used for GA calculation

K = common_params_df$K
S = common_params_df$S
alpha = common_params_df$alpha


##Spend dataframe
# data.XyZ = read.csv('MMA_final_data_with_30DMAs_v7.csv')
# data.XyZ = data.XyZ %>% 
#             #dplyr::select(-X) %>%
#             dplyr::rename(period = calendar_month, dma = DMA) %>%
#             dplyr::mutate(brand  = ifelse(dma == "NEW YORK, NY", "Optimum", "Suddenlink"),
#                           period = lubridate::as_date(period)) %>% 
#             dplyr::select(brand, dma, period, everything()) %>% 
#             dplyr::arrange(dma, period)


##Count of DMAs,medias and periods
nbr_media    = length(media_names_vec)
nbr_dma      = length(dma_names_vec)
nbr_periods  = data_XyZ %>% select(period) %>% distinct() %>% count(n()) %>% pull()
nbr_period_q = 13
n_weeks_mat = mean_n_weeks %>% rename_at(.vars = vars(spend_cols_vec), .funs = ~media_names_vec) %>% select(media_names_vec) %>% as.matrix()

target_var = 'weekly_gross_adds'
var_id_opt = which(dma_names_vec %in% optimum_dma)

# %%
n_weeks_mat
# Out:
#       tv        dm       paid_search_brand paid_search_unbranded display
#  [1,] 13.000000 13.00000 12.93333          12.93333              13.00000
#  [2,] 13.000000 13.00000 13.00000          13.00000              13.00000
#  [3,] 13.000000 13.00000 13.00000          13.00000              13.00000
#  [4,] 13.000000 13.00000 13.00000          12.93333              13.00000
#  [5,]  0.000000 13.00000 13.00000          13.00000              12.86667
#  [6,] 13.000000 13.00000 13.00000          13.00000              13.00000
#  [7,] 13.000000 13.00000 13.00000          13.00000              12.93333
#  [8,]  0.000000 13.00000 13.00000          13.00000              13.00000
#  [9,] 13.000000 13.00000 12.93333          12.80000              13.00000
# [10,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [11,]  0.000000 13.00000 13.00000          13.00000              13.00000
# [12,] 13.000000 13.00000 13.00000          12.86667              13.00000
# [13,] 12.266667 12.66667 13.00000          13.00000              12.93333
# [14,]  8.800000 13.00000 13.00000          12.93333              13.00000
# [15,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [16,] 12.933333 13.00000 12.93333          12.93333              13.00000
# [17,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [18,] 13.000000 13.00000 13.00000          12.93333              13.00000
# [19,]  1.733333 13.00000 13.00000          13.00000              13.00000
# [20,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [21,]  0.000000 13.00000 13.00000          13.00000              13.00000
# [22,]  0.000000 13.00000 13.00000          13.00000              13.00000
# [23,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [24,] 12.933333 13.00000 13.00000          13.00000              13.00000
# [25,] 12.200000 13.00000 13.00000          13.00000              13.00000
# [26,] 13.000000 13.00000 13.00000          12.93333              13.00000
# [27,]  1.666667 13.00000 13.00000          13.00000              12.93333
# [28,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [29,] 13.000000 13.00000 13.00000          13.00000              12.93333
# [30,] 13.000000 13.00000 13.00000          13.00000              13.00000
#       radio     video    print     social   audio
#  [1,] 11.466667 12.93333 2.2666667 12.80000 4.733333
#  [2,] 11.133333 13.00000 2.5333333 12.86667 4.133333
#  [3,] 11.600000 13.00000 2.5333333 13.00000 8.200000
#  [4,] 12.400000 12.66667 4.1333333 12.93333 3.800000
#  [5,]  7.800000 12.86667 4.6666667 12.93333 5.133333
#  [6,] 11.200000 13.00000 0.8000000 13.00000 5.133333
#  [7,] 11.066667 12.93333 1.4000000 12.93333 4.666667
#  [8,]  8.533333 13.00000 4.9333333 13.00000 6.000000
#  [9,] 10.466667 12.93333 1.0000000 12.93333 4.466667
# [10,] 10.200000 13.00000 1.6666667 12.66667 4.666667
# [11,]  7.800000 13.00000 5.2000000 12.86667 5.266667
# [12,] 11.066667 12.93333 2.6000000 12.80000 4.200000
# [13,] 11.933333 12.86667 2.8666667 12.86667 3.600000
# [14,] 10.133333 13.00000 1.4666667 12.93333 4.733333
# [15,] 12.400000 13.00000 4.0000000 12.80000 4.000000
# [16,] 10.000000 12.93333 1.4666667 12.80000 4.400000
# [17,] 11.866667 13.00000 7.7333333 13.00000 9.533333
# [18,] 11.200000 12.93333 2.2000000 12.73333 4.400000
# [19,]  9.866667 13.00000 2.6666667 12.66667 4.866667
# [20,] 11.466667 12.93333 1.0000000 12.80000 4.466667
# [21,]  8.666667 13.00000 2.0666667 12.80000 5.200000
# [22,]  2.466667 13.00000 0.5333333 12.66667 5.066667
# [23,] 12.400000 12.86667 2.4000000 12.73333 4.466667
# [24,] 10.400000 12.93333 3.2666667 12.60000 4.666667
# [25,]  7.533333 12.93333 0.5333333 12.93333 5.066667
# [26,] 11.333333 12.93333 0.5333333 12.80000 4.400000
# [27,]  6.333333 12.80000 1.4000000 12.86667 4.600000
# [28,] 10.333333 13.00000 2.7333333 12.80000 4.666667
# [29,] 12.333333 12.86667 0.5333333 12.80000 4.400000
# [30,]  9.866667 13.00000 1.0666667 12.73333 4.600000

# %%
model_params = list(
'media_params' = list(
'media_names_vec' = media_names_vec,
'beta_media_mat' = beta_media_mat,
'prospect_mat_media' = prospect_mat_media,
'K' = K,
'S' = S,
'alpha' = alpha,
'max_media_mat' = max_media_mat,
'min_media_mat' = min_media_mat,
'cleaned_names_list' = cleaned_names_list,
'spend_activity_ratio_dma_df' = spend_activity_ratio_dma_df,
'spend_cols_vec' = spend_cols_vec,
'n_weeks_mat' = n_weeks_mat
),
'control_params' = list(
'control_mat' = control_mat,
'control_names_vec' = control_names_vec,
'beta_control_mat' = beta_control_mat
),
'target_params' = list(
'target_var' = target_var,
'target_max_vec' = target_max_vec,
'target_capita_norm_col' = target_capita_norm_col
),    
'other_params' = list(
'nbr_period_q' = nbr_period_q,
'dma_names_vec' = dma_names_vec,
'optimum_dma' = optimum_dma
)
)

# %%
n_media = length(media_names_vec)
n_geo = length(dma_names_vec)
n_control = length(control_names_vec)

# %%
var_media = model_params$media_params$spend_cols_vec
var_media
# Out:
#  [1] "tv_spend"                    "dm_spend"
#  [3] "paid_search_spend_brand"     "paid_search_spend_unbranded"
#  [5] "display_spend"               "radio_spend"
#  [7] "video_spend"                 "print_spend"
#  [9] "social_spend"                "audio_spend"

# %%
fit_metrics_mean_df <- fit_metrics_df %>%
                        mutate(group = toupper(group),
                               metric = toupper(metric)) %>%
                        filter(metric %in% c('R2','MAPE') & sample_type == 'Train') %>%
                        select(dma = group,metric,Mean) %>%
                        spread(metric,Mean)

fit_metrics_mean_df
# Out:
#    dma                            MAPE      R2
# 1  ABILENE-SWEETWATER TX           9.520066 0.6195612
# 2  ALEXANDRIA LA                  18.579002 0.6129892
# 3  ALL OTHER SUDDENLINK DMA TOTAL 10.267704 0.3706562
# 4  ALTICE                          4.728855 0.8086054
# 5  AMARILLO TX                     7.917886 0.6511672
# 6  AUSTIN TX                       9.281031 0.8255919
# 7  BLUEFIELD-BECKLEY-OAK HILL WV  10.282910 0.5708710
# 8  CHARLESTON-HUNTINGTON WV        8.437292 0.5370957
# 9  DALLAS-FT WORTH TX              8.475573 0.7976624
# 10 EUREKA CA                      11.729943 0.7029302
# 11 GREENVILLE-NEW BERN-WASH NC    10.141492 0.7339151
# 12 HOUSTON TX                      8.265704 0.7672977
# 13 JONESBORO AR                   10.198618 0.7333181
# 14 LAKE CHARLES LA                31.172402 0.5662834
# 15 LITTLE ROCK AR                  9.627379 0.5700372
# 16 LUBBOCK TX                      9.300264 0.8112237
# 17 MONROE-EL DORADO LA-AR         15.475481 0.6464353
# 18 NEW YORK, NY                    6.876066 0.6721140
# 19 ODESSA-MIDLAND TX               9.126972 0.5500093
# 20 OKLAHOMA CITY OK                9.920871 0.8522427
# 21 OPTIMUM                         6.876066 0.6721140
# 22 PARKERSBURG WV                 13.775904 0.5813872
# 23 PHOENIX AZ                      7.436470 0.6798022
# 24 RALEIGH-DURHAM NC              14.050719 0.5489698
# 25 SAN ANGELO TX                  11.309096 0.5478538
# 26 SHREVEPORT LA                  10.227460 0.7177651
# 27 SPRINGFIELD MO                  8.462830 0.5843180
# 28 ST JOSEPH MO                   11.104079 0.6089397
# 29 SUDDENLINK                      4.902547 0.8566778
# 30 TULSA OK                       11.450010 0.5257289
# 31 TYLER-LONGVIEW TX               8.114254 0.8294923
# 32 VICTORIA TX                    11.998031 0.5762349
# 33 WACO-TEMPLE-BRYAN TX           15.943345 0.8117888

# %% [markdown]
# ### Computing using the mean of all parameters

# %%
res <- compute_elasticity_and_contribution(model_params = model_params,
                                              mean_qy_spend = mean_qy_spend,
                                            mean_weekly_spend = mean_weekly_spend,
                                           activity_based_media = NULL,
                                           data_XyZ = data_XyZ,
                                             spend_change = c(0.1,0.3))
# Out:
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.
#
# Adding missing grouping variables: `qy`
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(control_names)` instead of `control_names` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.
#
# Adding missing grouping variables: `qy`
#
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.
#
# Adding missing grouping variables: `qy`
#
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.
#
# Adding missing grouping variables: `qy`
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(display_order)` instead of `display_order` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(var_Elasticity_up)` instead of `var_Elasticity_up` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(var_Elasticity_down)` instead of `var_Elasticity_down` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
# Order of media:
# 1.tv
# 2.dm
# 3.paid_search_brand
# 4.paid_search_unbranded
# 5.display
# 6.radio
# 7.video
# 8.print
# 9.social
# 10.audio
# 11.total

# %%
res$Elasticity$`Elasticity_up_0.1`
# Out:
# [[1]]
# # A tibble: 33 × 12
#    dma            tv    dm paid_search_bra… paid_search_unb… display radio video
#    <fct>       <dbl> <dbl>            <dbl>            <dbl>   <dbl> <dbl> <dbl>
#  1 ALTICE       0.24  0.09             0.8              0.05    0.05  0.02  0.02
#  2 SUDDENLINK   0.19  0.06             0.95             0.06    0.04  0.03  0.01
#  3 OPTIMUM      0.29  0.12             0.71             0.04    0.06  0     0.03
#  4 ABILENE-S…   0.15  0.04             0.87             0.02    0.01  0     0
#  5 ALEXANDRI…   0.21  0.05             0.54             0.02    0     0     0
#  6 All Other…   0.34  0.07             0.66             0.16    0.13  0.02  0.05
#  7 AMARILLO …   0.18  0.05             0.76             0.01    0     0     0
#  8 AUSTIN TX  NaN     0.06             0.8              0.13    0.08  0.09  0.03
#  9 BLUEFIELD…   0.21  0.04             0.83             0.01    0.01  0.01  0
# 10 CHARLESTO…   0.17  0.03             0.48             0.02    0.01  0     0.01
# # … with 23 more rows, and 4 more variables: print <dbl>, social <dbl>,
# #   audio <dbl>, spend_media_total <dbl>

# %%
res$All_metrics_detailed
# Out:
#     dma                  media                 mean_spend Media_GA
# 1   ALTICE               tv                    12815856   
0.00              0.00
# ⋮   ⋮                 ⋮          ⋮                 ⋮
# 367   0.158351242     6051       0.01              0.00
# 368   0.586252546     6051       0.05              0.04
# 369   0.633387226     6051       0.02              0.01
# 370   0.002283650     6051       0.00              0.00
# 371 304.698035659     6051       0.13              0.12
# 372 304.698035659     6051       0.13              0.12
# 373 103.531699978     1014       0.00              0.01
# 374   2.132127511     1014       0.14              0.11
# 375  31.356934444     1014       1.26              1.21
# 376   0.233107693     1014       0.03              0.03
# 377   0.049170062     1014       0.01              0.01
# 378   0.605809593     1014       0.06              0.05
# 379   0.018458654     1014       0.01              0.01
# 380   0.103468057     1014       0.21              0.18
# 381   0.104085977     1014       0.03              0.02
# 382   0.000407505     1014       0.00              0.00
# 383 138.135269474     1014       0.10              0.10
# 384 138.135269474     1014       0.10              0.10
# 385 125.045162072     4003       0.14              0.14
# 386   3.212142563     4003       0.04              0.03
# 387 212.790686568     4003       1.55              1.49
# 388   0.840848956     4003       0.02              0.01
# 389   0.547476753     4003       0.01              0.01
# 390   0.041535916     4003       0.00              0.00
# 391   0.080374444     4003       0.00              0.00
# 392   0.138561688     4003       0.04              0.03
# 393   0.214110178     4003       0.01              0.01
# 394   0.001589195     4003       0.00              0.00
# 395 342.912488333     4003       0.19              0.18
# 396 342.912488333     4003       0.19              0.18
#     Elasticity_up_0.3 Elasticity_down_0.3
# 1   0.24              0.26
# 2   0.11              0.06
# 3   0.83              0.73
# 4   0.06              0.03
# 5   0.06              0.03
# 6   0.03              0.01
# 7   0.03              0.02
# 8   0.07              0.04
# 9   0.03              0.02
# 10  0.01              0.01
# 11  0.19              0.17
# 12  0.19              0.17
# 13  0.18              0.19
# 14  0.08              0.04
# 15  0.99              0.86
# 16  0.07              0.04
# 17  0.05              0.03
# 18  0.04              0.02
# 19  0.02              0.01
# 20  0.08              0.05
# 21  0.02              0.01
# 22  0.01              0.01
# 23  0.16              0.13
# 24  0.16              0.13
# 25  0.28              0.31
# 26  0.15              0.08
# 27  0.73              0.66
# 28  0.05              0.03
# 29  0.07              0.04
# 30  0.00              0.00
# ⋮   ⋮                 ⋮
# 367 0.01              0.00
# 368 0.05              0.03
# 369 0.02              0.01
# 370 0.00              0.00
# 371 0.14              0.11
# 372 0.14              0.11
# 373 0.00              0.12
# 374 0.17              0.09
# 375 1.30              1.16
# 376 0.04              0.02
# 377 0.01              0.01
# 378 0.08              0.04
# 379 0.01              0.00
# 380 0.24              0.15
# 381 0.03              0.02
# 382 0.00              0.00
# 383 0.11              0.15
# 384 0.11              0.15
# 385 0.14              0.14
# 386 0.05              0.03
# 387 1.61              1.41
# 388 0.02              0.01
# 389 0.02              0.01
# 390 0.00              0.00
# 391 0.00              0.00
# 392 0.05              0.03
# 393 0.01              0.01
# 394 0.00              0.00
# 395 0.19              0.17
# 396 0.19              0.17

# %%
mean_metrics_df <- res$All_metrics_detailed %>%
                   left_join(fit_metrics_mean_df)
mean_metrics_df
# Out:
# Joining, by = "dma"
#     dma                  media                 mean_spend Media_GA
# 1   ALTICE               tv                    12815856   
# 381 0.03              0.02                11.998031 0.5762349
# 382 0.00              0.00                11.998031 0.5762349
# 383 0.11              0.15                11.998031 0.5762349
# 384 0.11              0.15                11.998031 0.5762349
# 385 0.14              0.14                15.943345 0.8117888
# 386 0.05              0.03                15.943345 0.8117888
# 387 1.61              1.41                15.943345 0.8117888
# 388 0.02              0.01                15.943345 0.8117888
# 389 0.02              0.01                15.943345 0.8117888
# 390 0.00              0.00                15.943345 0.8117888
# 391 0.00              0.00                15.943345 0.8117888
# 392 0.05              0.03                15.943345 0.8117888
# 393 0.01              0.01                15.943345 0.8117888
# 394 0.00              0.00                15.943345 0.8117888
# 395 0.19              0.17                15.943345 0.8117888
# 396 0.19              0.17                15.943345 0.8117888

# %%
using_mean_plts <- gen_contrib_elas_plots(mean_metrics_df,activity_based_media,'Elasticity_up_0.1')

# %%
options(repr.plot.width=8, repr.plot.height = 8)
using_mean_plts$brand_plots$ALTICE
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height = 8)
using_mean_plts$brand_plots$SUDDENLINK
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height = 8)
using_mean_plts$brand_plots$OPTIMUM
# Out:
# plot without title

# %%
save(model_params,file = 'model_params/model_params_PP_44_10_C18_xy995.rda')

# %% [markdown]
# ## PP_44_10_C19_xy995

# %%
load('Optimization_results/Optimizer_PP_44_10_C19_xy995.RData')

# %%
load('MCMC_objs/MCMC_objs_EVA_PP_44_10_C19_xy995.rda')

# %%
MCMC_beta_media <- MCMC_objs$beta_media
MCMC_beta_base_control <- MCMC_objs$beta_base_control
MCMC_alpha_K_S <- MCMC_objs$alpha_K_S
fit_metrics_df <- MCMC_objs$eval_metrics

# %%
## Naming the model results with the corresponding actual target name
## Get the geo dfs list
names_geo_df           = ls(pattern='*44_10_C19.*geo_para')
res_geo_df_list        = c()
res_geo_df_list        <- lapply(names_geo_df,FUN = function(x){append(res_geo_df_list,setNames(list(as.data.frame(get(x))),x),0)})
names(res_geo_df_list) = target_cols

## Get the population dfs list
names_pop_df           = ls(pattern='*44_10_C19.*pop_para')
res_pop_df_list        = c()
res_pop_df_list        <- lapply(names_pop_df,FUN = function(x){append(res_pop_df_list,setNames(list(as.data.frame(get(x))),x),0)})
names(res_pop_df_list) = target_cols
target_norm_cols <- 'non_sub'

# %%
names_geo_df
names_pop_df
# Out:
# [1] "PP_44_10_C19_xy995_geo_para_stat"
# [1] "PP_44_10_C19_xy995_pop_para_stat"

# %%
test_extraction <- make_optim_data_mmm(data_XyZ              = data_XyZ,
                                               list_pop_param_df     = res_pop_df_list,
                                               list_geo_param_df     = res_geo_df_list,
                                               target_names_vec      = target_cols,
                                               list_preprocessed_data= pp_MMM_ts_comp_xy995,
                                               media_norm_type       = 4,
                                               target_norm_type      = 4,
                                               pooling_type = 'partial',
                                               target_norm_cols = target_norm_cols
                                               )
# Out:
# DMA names:
# 1 ABILENE-SWEETWATER TX
# 2 ALEXANDRIA LA
# 3 All Other Suddenlink DMA Total
# 4 AMARILLO TX
# 5 AUSTIN TX
# 6 BLUEFIELD-BECKLEY-OAK HILL WV
# 7 CHARLESTON-HUNTINGTON WV
# 8 DALLAS-FT WORTH TX
# 9 EUREKA CA
# 10 GREENVILLE-NEW BERN-WASH NC
# 11 HOUSTON TX
# 12 JONESBORO AR
# 13 LAKE CHARLES LA
# 14 LITTLE ROCK AR
# 15 LUBBOCK TX
# 16 MONROE-EL DORADO LA-AR
# 17 NEW YORK, NY
# 18 ODESSA-MIDLAND TX
# 19 OKLAHOMA CITY OK
# 20 PARKERSBURG WV
# 21 PHOENIX AZ
# 22 RALEIGH-DURHAM NC
# 23 SAN ANGELO TX
# 24 SHREVEPORT LA
# 25 SPRINGFIELD MO
# 26 ST JOSEPH MO
# 27 TULSA OK
# 28 TYLER-LONGVIEW TX
# 29 VICTORIA TX
# 30 WACO-TEMPLE-BRYAN TX
# media names:
# 1 tv_spend
# 2 dm_spend
# 3 paid_search_spend_brand
# 4 paid_search_spend_unbranded
# 5 display_spend
# 6 radio_spend
# 7 video_spend
# 8 print_spend
# 9 social_spend
# 10 audio_spend
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(final_data_cols)` instead of `final_data_cols` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# Adding missing grouping variables: `dma_id`, `dma`, `X`
#
# Adding missing grouping variables: `dma_id`, `dma`, `X`
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(control_names_vec)` instead of `control_names_vec` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.

# %%
# Outputs from `make_optim_data_mmm`
spend_cols_vec    = test_extraction$gross_add_true$media$spend_cols_vec
media_names_vec   = test_extraction$gross_add_true$media$media_names_vec
dma_names_vec     = test_extraction$gross_add_true$other$dma_names_vec
common_params_df  = test_extraction$gross_add_true$media$common_params_df
beta_media_mat    = test_extraction$gross_add_true$media$beta_media_mat
beta_control_mat  = test_extraction$gross_add_true$control$beta_control_mat
min_media_mat     = test_extraction$gross_add_true$media$min_media_mat
max_media_mat     = test_extraction$gross_add_true$media$max_media_mat
prospect_df       = test_extraction$gross_add_true$other$prospect_df
control_names_vec = test_extraction$gross_add_true$control$control_names_vec
control_mat       = test_extraction$gross_add_true$control$control_matrix
target_max_vec    = test_extraction$gross_add_true$target$target_max_vec
subs_col          = test_extraction$gross_add_true$other$subs_col
cleaned_names_list = test_extraction$gross_add_true$media$cleaned_media_names_vec
target_capita_norm_col = test_extraction$gross_add_true$target$target_capita_norm_col

# %%
prospect_vec = prospect_df[['non_sub']]
prospect_mat_media = matrix(prospect_vec,nrow = length(dma_names_vec), ncol = length(media_names_vec))

# %%
#*************  Simulator for Optimization  ***************************

###################################################################################################################################
#Global parameters needed for optimization
###################################################################################################################################
##Vector of Optimum DMA
optimum_dma =  c('NEW YORK, NY')
non_tv_dmas = mean_weekly_spend %>%
                mutate(dma_id = row_number(dma)) %>%
                filter(tv_spend == 0) %>%
                select(dma_id) %>%
                pull()


# media_names_vec = c('cross_channel','DM','outbound_call')


##Spend to activity ratio dataframe by DMA and media. Used primarily for activity based models for converting the activity to spend for optimization_ Dim - ndma*nmedia
spend_activity_ratio_dma_df <- as.data.frame(matrix(1, length(dma_names_vec), length(media_names_vec)))
colnames(spend_activity_ratio_dma_df) <- media_names_vec
spend_activity_ratio_dma_df[non_tv_dmas,'tv'] <- 0 

##Shape parameters used for GA calculation

K = common_params_df$K
S = common_params_df$S
alpha = common_params_df$alpha


##Spend dataframe
# data.XyZ = read.csv('MMA_final_data_with_30DMAs_v7.csv')
# data.XyZ = data.XyZ %>% 
#             #dplyr::select(-X) %>%
#             dplyr::rename(period = calendar_month, dma = DMA) %>%
#             dplyr::mutate(brand  = ifelse(dma == "NEW YORK, NY", "Optimum", "Suddenlink"),
#                           period = lubridate::as_date(period)) %>% 
#             dplyr::select(brand, dma, period, everything()) %>% 
#             dplyr::arrange(dma, period)


##Count of DMAs,medias and periods
nbr_media    = length(media_names_vec)
nbr_dma      = length(dma_names_vec)
nbr_periods  = data_XyZ %>% select(period) %>% distinct() %>% count(n()) %>% pull()
nbr_period_q = 13
n_weeks_mat = mean_n_weeks %>% rename_at(.vars = vars(spend_cols_vec), .funs = ~media_names_vec) %>% select(media_names_vec) %>% as.matrix()

target_var = 'weekly_gross_adds'
var_id_opt = which(dma_names_vec %in% optimum_dma)
# Out:
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(spend_cols_vec)` instead of `spend_cols_vec` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(media_names_vec)` instead of `media_names_vec` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.

# %%
n_weeks_mat
# Out:
#       tv        dm       paid_search_brand paid_search_unbranded display
#  [1,] 13.000000 13.00000 12.93333          12.93333              13.00000
#  [2,] 13.000000 13.00000 13.00000          13.00000              13.00000
#  [3,] 13.000000 13.00000 13.00000          13.00000              13.00000
#  [4,] 13.000000 13.00000 13.00000          12.93333              13.00000
#  [5,]  0.000000 13.00000 13.00000          13.00000              12.86667
#  [6,] 13.000000 13.00000 13.00000          13.00000              13.00000
#  [7,] 13.000000 13.00000 13.00000          13.00000              12.93333
#  [8,]  0.000000 13.00000 13.00000          13.00000              13.00000
#  [9,] 13.000000 13.00000 12.93333          12.80000              13.00000
# [10,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [11,]  0.000000 13.00000 13.00000          13.00000              13.00000
# [12,] 13.000000 13.00000 13.00000          12.86667              13.00000
# [13,] 12.266667 12.66667 13.00000          13.00000              12.93333
# [14,]  8.800000 13.00000 13.00000          12.93333              13.00000
# [15,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [16,] 12.933333 13.00000 12.93333          12.93333              13.00000
# [17,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [18,] 13.000000 13.00000 13.00000          12.93333              13.00000
# [19,]  1.733333 13.00000 13.00000          13.00000              13.00000
# [20,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [21,]  0.000000 13.00000 13.00000          13.00000              13.00000
# [22,]  0.000000 13.00000 13.00000          13.00000              13.00000
# [23,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [24,] 12.933333 13.00000 13.00000          13.00000              13.00000
# [25,] 12.200000 13.00000 13.00000          13.00000              13.00000
# [26,] 13.000000 13.00000 13.00000          12.93333              13.00000
# [27,]  1.666667 13.00000 13.00000          13.00000              12.93333
# [28,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [29,] 13.000000 13.00000 13.00000          13.00000              12.93333
# [30,] 13.000000 13.00000 13.00000          13.00000              13.00000
#       radio     video    print     social   audio
#  [1,] 11.466667 12.93333 2.2666667 12.80000 4.733333
#  [2,] 11.133333 13.00000 2.5333333 12.86667 4.133333
#  [3,] 11.600000 13.00000 2.5333333 13.00000 8.200000
#  [4,] 12.400000 12.66667 4.1333333 12.93333 3.800000
#  [5,]  7.800000 12.86667 4.6666667 12.93333 5.133333
#  [6,] 11.200000 13.00000 0.8000000 13.00000 5.133333
#  [7,] 11.066667 12.93333 1.4000000 12.93333 4.666667
#  [8,]  8.533333 13.00000 4.9333333 13.00000 6.000000
#  [9,] 10.466667 12.93333 1.0000000 12.93333 4.466667
# [10,] 10.200000 13.00000 1.6666667 12.66667 4.666667
# [11,]  7.800000 13.00000 5.2000000 12.86667 5.266667
# [12,] 11.066667 12.93333 2.6000000 12.80000 4.200000
# [13,] 11.933333 12.86667 2.8666667 12.86667 3.600000
# [14,] 10.133333 13.00000 1.4666667 12.93333 4.733333
# [15,] 12.400000 13.00000 4.0000000 12.80000 4.000000
# [16,] 10.000000 12.93333 1.4666667 12.80000 4.400000
# [17,] 11.866667 13.00000 7.7333333 13.00000 9.533333
# [18,] 11.200000 12.93333 2.2000000 12.73333 4.400000
# [19,]  9.866667 13.00000 2.6666667 12.66667 4.866667
# [20,] 11.466667 12.93333 1.0000000 12.80000 4.466667
# [21,]  8.666667 13.00000 2.0666667 12.80000 5.200000
# [22,]  2.466667 13.00000 0.5333333 12.66667 5.066667
# [23,] 12.400000 12.86667 2.4000000 12.73333 4.466667
# [24,] 10.400000 12.93333 3.2666667 12.60000 4.666667
# [25,]  7.533333 12.93333 0.5333333 12.93333 5.066667
# [26,] 11.333333 12.93333 0.5333333 12.80000 4.400000
# [27,]  6.333333 12.80000 1.4000000 12.86667 4.600000
# [28,] 10.333333 13.00000 2.7333333 12.80000 4.666667
# [29,] 12.333333 12.86667 0.5333333 12.80000 4.400000
# [30,]  9.866667 13.00000 1.0666667 12.73333 4.600000

# %%
model_params = list(
'media_params' = list(
'media_names_vec' = media_names_vec,
'beta_media_mat' = beta_media_mat,
'prospect_mat_media' = prospect_mat_media,
'K' = K,
'S' = S,
'alpha' = alpha,
'max_media_mat' = max_media_mat,
'min_media_mat' = min_media_mat,
'cleaned_names_list' = cleaned_names_list,
'spend_activity_ratio_dma_df' = spend_activity_ratio_dma_df,
'spend_cols_vec' = spend_cols_vec,
'n_weeks_mat' = n_weeks_mat
),
'control_params' = list(
'control_mat' = control_mat,
'control_names_vec' = control_names_vec,
'beta_control_mat' = beta_control_mat
),
'target_params' = list(
'target_var' = target_var,
'target_max_vec' = target_max_vec,
'target_capita_norm_col' = target_capita_norm_col
),    
'other_params' = list(
'nbr_period_q' = nbr_period_q,
'dma_names_vec' = dma_names_vec,
'optimum_dma' = optimum_dma
)
)

# %%
n_media = length(media_names_vec)
n_geo = length(dma_names_vec)
n_control = length(control_names_vec)

# %%
var_media = model_params$media_params$spend_cols_vec
var_media
# Out:
#  [1] "tv_spend"                    "dm_spend"
#  [3] "paid_search_spend_brand"     "paid_search_spend_unbranded"
#  [5] "display_spend"               "radio_spend"
#  [7] "video_spend"                 "print_spend"
#  [9] "social_spend"                "audio_spend"

# %%
fit_metrics_mean_df <- fit_metrics_df %>%
                        mutate(group = toupper(group),
                               metric = toupper(metric)) %>%
                        filter(metric %in% c('R2','MAPE') & sample_type == 'Train') %>%
                        select(dma = group,metric,Mean) %>%
                        spread(metric,Mean)

fit_metrics_mean_df
# Out:
#    dma                            MAPE      R2
# 1  ABILENE-SWEETWATER TX           9.702124 0.6075772
# 2  ALEXANDRIA LA                  18.722820 0.6107849
# 3  ALL OTHER SUDDENLINK DMA TOTAL  9.880165 0.4108744
# 4  ALTICE                          4.810259 0.8030125
# 5  AMARILLO TX                     8.037508 0.6447744
# 6  AUSTIN TX                       9.405111 0.8239596
# 7  BLUEFIELD-BECKLEY-OAK HILL WV  10.078353 0.5883418
# 8  CHARLESTON-HUNTINGTON WV        8.500418 0.5360226
# 9  DALLAS-FT WORTH TX              8.677383 0.7887063
# 10 EUREKA CA                      11.557014 0.7058839
# 11 GREENVILLE-NEW BERN-WASH NC    10.161126 0.7326366
# 12 HOUSTON TX                      8.175294 0.7715386
# 13 JONESBORO AR                   10.290822 0.7298834
# 14 LAKE CHARLES LA                31.350760 0.5613099
# 15 LITTLE ROCK AR                  9.695239 0.5723054
# 16 LUBBOCK TX                      9.557204 0.7981572
# 17 MONROE-EL DORADO LA-AR         15.724876 0.6436234
# 18 NEW YORK, NY                    6.886315 0.6675234
# 19 ODESSA-MIDLAND TX               9.298268 0.5389009
# 20 OKLAHOMA CITY OK                9.982775 0.8497817
# 21 OPTIMUM                         6.886315 0.6675234
# 22 PARKERSBURG WV                 13.594801 0.5928390
# 23 PHOENIX AZ                      7.368771 0.6822813
# 24 RALEIGH-DURHAM NC              14.201884 0.5391204
# 25 SAN ANGELO TX                  11.394966 0.5448721
# 26 SHREVEPORT LA                  10.334724 0.7130373
# 27 SPRINGFIELD MO                  8.608301 0.5824722
# 28 ST JOSEPH MO                   11.578275 0.5807329
# 29 SUDDENLINK                      5.291978 0.8430196
# 30 TULSA OK                       11.443163 0.5264706
# 31 TYLER-LONGVIEW TX               8.742668 0.8112265
# 32 VICTORIA TX                    12.119230 0.5743672
# 33 WACO-TEMPLE-BRYAN TX           16.837366 0.8004645

# %% [markdown]
# ### Computing using the mean of all parameters

# %%
res <- compute_elasticity_and_contribution(model_params = model_params,
                                              mean_qy_spend = mean_qy_spend,
                                            mean_weekly_spend = mean_weekly_spend,
                                           activity_based_media = NULL,
                                           data_XyZ = data_XyZ,
                                             spend_change = c(0.1,0.3))
# Out:
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.
#
# Adding missing grouping variables: `qy`
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(control_names)` instead of `control_names` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.
#
# Adding missing grouping variables: `qy`
#
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.
#
# Adding missing grouping variables: `qy`
#
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.
#
# Adding missing grouping variables: `qy`
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(display_order)` instead of `display_order` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(var_Elasticity_up)` instead of `var_Elasticity_up` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(var_Elasticity_down)` instead of `var_Elasticity_down` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
# Order of media:
# 1.tv
# 2.dm
# 3.paid_search_brand
# 4.paid_search_unbranded
# 5.display
# 6.radio
# 7.video
# 8.print
# 9.social
# 10.audio
# 11.total

# %%
res$Elasticity$`Elasticity_up_0.1`
# Out:
# [[1]]
# # A tibble: 33 × 12
#    dma            tv    dm paid_search_bra… paid_search_unb… display radio video
#    <fct>       <dbl> <dbl>            <dbl>            <dbl>   <dbl> <dbl> <dbl>
#  1 ALTICE       0.24  0.09             0.86             0.05    0.04  0.02  0.02
#  2 SUDDENLINK   0.19  0.06             1.04             0.06    0.03  0.03  0.01
#  3 OPTIMUM      0.29  0.11             0.74             0.04    0.04  0     0.03
#  4 ABILENE-S…   0.15  0.04             1.09             0.02    0     0     0
#  5 ALEXANDRI…   0.21  0.05             0.53             0.01    0     0     0
#  6 All Other…   0.34  0.07             0.72             0.15    0.1   0.02  0.05
#  7 AMARILLO …   0.18  0.05             0.89             0.01    0     0     0
#  8 AUSTIN TX  NaN     0.06             0.85             0.13    0.06  0.09  0.02
#  9 BLUEFIELD…   0.21  0.04             0.78             0.01    0     0.01  0
# 10 CHARLESTO…   0.17  0.02             0.52             0.01    0.01  0     0.01
# # … with 23 more rows, and 4 more variables: print <dbl>, social <dbl>,
# #   audio <dbl>, spend_media_total <dbl>

# %%
res$All_metrics_detailed
# Out:
#     dma                  media                 mean_spend Media_GA
# 1   ALTICE               tv                    12815856   
# 376   0.2158881532    1016       0.03              0.03
# 377   0.0318895207    1016       0.01              0.01
# 378   0.5819650408    1016       0.06              0.05
# 379   0.0145975238    1016       0.01              0.00
# 380   0.1060436495    1016       0.22              0.19
# 381   0.0878082153    1016       0.02              0.02
# 382   0.0003887343    1016       0.00              0.00
# 383 138.4145241253    1016       0.10              0.10
# 384 138.4145241253    1016       0.10              0.10
# 385 126.7874234836    3926       0.14              0.14
# 386   3.0057122448    3926       0.04              0.03
# 387 252.6011885803    3926       1.87              1.79
# 388   0.7759907994    3926       0.02              0.01
# 389   0.3551433410    3926       0.01              0.01
# 390   0.0387192804    3926       0.00              0.00
# 391   0.0633863366    3926       0.00              0.00
# 392   0.1277468501    3926       0.04              0.03
# 393   0.1894853231    3926       0.01              0.01
# 394   0.0015215713    3926       0.00              0.00
# 395 383.9463178106    3926       0.21              0.20
# 396 383.9463178106    3926       0.21              0.20
#     Elasticity_up_0.3 Elasticity_down_0.3
# 1   0.23              0.26
# 2   0.11              0.06
# 3   0.89              0.78
# 4   0.06              0.03
# 5   0.05              0.02
# 6   0.03              0.01
# 7   0.02              0.01
# 8   0.07              0.04
# 9   0.03              0.02
# 10  0.01              0.01
# 11  0.19              0.17
# 12  0.19              0.17
# 13  0.18              0.19
# 14  0.07              0.04
# 15  1.08              0.94
# 16  0.07              0.04
# 17  0.04              0.02
# 18  0.04              0.02
# 19  0.02              0.01
# 20  0.08              0.05
# 21  0.02              0.01
# 22  0.01              0.01
# 23  0.16              0.14
# 24  0.16              0.14
# 25  0.28              0.31
# 26  0.14              0.07
# 27  0.76              0.69
# 28  0.05              0.02
# 29  0.05              0.03
# 30  0.00              0.00
# ⋮   ⋮                 ⋮
# 367 0.01              0.00
# 368 0.05              0.03
# 369 0.02              0.01
# 370 0.00              0.00
# 371 0.15              0.13
# 372 0.15              0.13
# 373 0.00              0.12
# 374 0.16              0.08
# 375 1.34              1.19
# 376 0.04              0.02
# 377 0.01              0.01
# 378 0.07              0.04
# 379 0.01              0.00
# 380 0.25              0.16
# 381 0.03              0.02
# 382 0.00              0.00
# 383 0.11              0.15
# 384 0.11              0.15
# 385 0.14              0.14
# 386 0.05              0.02
# 387 1.94              1.69
# 388 0.02              0.01
# 389 0.01              0.01
# 390 0.00              0.00
# 391 0.00              0.00
# 392 0.05              0.03
# 393 0.01              0.01
# 394 0.00              0.00
# 395 0.22              0.19
# 396 0.22              0.19

# %%
mean_metrics_df <- res$All_metrics_detailed %>%
                   left_join(fit_metrics_mean_df)
mean_metrics_df
# Out:
# Joining, by = "dma"
#     dma                  media                 mean_spend Media_GA
# 1   ALTICE               tv                    12815856   14847.665266
# 2   ALTICE               dm                     8281353    1046.519484
# 3   ALTICE               paid_search_brand      3428487   10230.812834
# 4   ALTICE               paid_search_unbranded  4672666     355.404059
# 5   ALTICE               display                4229179     230.576874
# 6   ALTICE               radio                  2010964      66.974319
# 7   ALTICE               video                  2557005      79.550849
# 8   ALTICE               print                   363018      40.078734
# 9   ALTICE               social                 1568001      59.323894
# 10  ALTICE               audio                   130178       1.899968
# 11  ALTICE               spend_media_total     40056706   26958.806279
# 387 1.94              1.69                16.837366 0.8004645
# 388 0.02              0.01                16.837366 0.8004645
# 389 0.01              0.01                16.837366 0.8004645
# 390 0.00              0.00                16.837366 0.8004645
# 391 0.00              0.00                16.837366 0.8004645
# 392 0.05              0.03                16.837366 0.8004645
# 393 0.01              0.01                16.837366 0.8004645
# 394 0.00              0.00                16.837366 0.8004645
# 395 0.22              0.19                16.837366 0.8004645
# 396 0.22              0.19                16.837366 0.8004645

# %%
using_mean_plts <- gen_contrib_elas_plots(mean_metrics_df,activity_based_media,'Elasticity_up_0.1')

# %%
options(repr.plot.width=8, repr.plot.height = 8)
using_mean_plts$brand_plots$ALTICE
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height = 8)
using_mean_plts$brand_plots$SUDDENLINK
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height = 8)
using_mean_plts$brand_plots$OPTIMUM
# Out:
# plot without title

# %%
save(model_params,file = 'model_params/model_params_PP_44_10_C19_xy995.rda')

# %% [markdown]
# ## PP_44_10_C19_beta_res_xy995

# %%
load('Optimization_results/Optimizer_PP_44_10_C19_beta_res_xy995.RData')

# %%
load('MCMC_objs/MCMC_objs_EVA_PP_44_10_C19_beta_res_xy995.rda')

# %%
MCMC_beta_media <- MCMC_objs$beta_media
MCMC_beta_base_control <- MCMC_objs$beta_base_control
MCMC_alpha_K_S <- MCMC_objs$alpha_K_S
fit_metrics_df <- MCMC_objs$eval_metrics

# %%
## Naming the model results with the corresponding actual target name
## Get the geo dfs list
names_geo_df           = ls(pattern='*44_10_C19_beta_res.*geo_para')
res_geo_df_list        = c()
res_geo_df_list        <- lapply(names_geo_df,FUN = function(x){append(res_geo_df_list,setNames(list(as.data.frame(get(x))),x),0)})
names(res_geo_df_list) = target_cols

## Get the population dfs list
names_pop_df           = ls(pattern='*44_10_C19_beta_res.*pop_para')
res_pop_df_list        = c()
res_pop_df_list        <- lapply(names_pop_df,FUN = function(x){append(res_pop_df_list,setNames(list(as.data.frame(get(x))),x),0)})
names(res_pop_df_list) = target_cols
target_norm_cols <- 'non_sub'

# %%
names_geo_df
names_pop_df
# Out:
# [1] "PP_44_10_C19_beta_res_xy995_geo_para_stat"
# [1] "PP_44_10_C19_beta_res_xy995_pop_para_stat"

# %%
test_extraction <- make_optim_data_mmm(data_XyZ              = data_XyZ,
                                               list_pop_param_df     = res_pop_df_list,
                                               list_geo_param_df     = res_geo_df_list,
                                               target_names_vec      = target_cols,
                                               list_preprocessed_data= pp_MMM_ts_comp_xy995,
                                               media_norm_type       = 4,
                                               target_norm_type      = 4,
                                               pooling_type = 'partial',
                                               target_norm_cols = target_norm_cols
                                               )
# Out:
# DMA names:
# 1 ABILENE-SWEETWATER TX
# 2 ALEXANDRIA LA
# 3 All Other Suddenlink DMA Total
# 4 AMARILLO TX
# 5 AUSTIN TX
# 6 BLUEFIELD-BECKLEY-OAK HILL WV
# 7 CHARLESTON-HUNTINGTON WV
# 8 DALLAS-FT WORTH TX
# 9 EUREKA CA
# 10 GREENVILLE-NEW BERN-WASH NC
# 11 HOUSTON TX
# 12 JONESBORO AR
# 13 LAKE CHARLES LA
# 14 LITTLE ROCK AR
# 15 LUBBOCK TX
# 16 MONROE-EL DORADO LA-AR
# 17 NEW YORK, NY
# 18 ODESSA-MIDLAND TX
# 19 OKLAHOMA CITY OK
# 20 PARKERSBURG WV
# 21 PHOENIX AZ
# 22 RALEIGH-DURHAM NC
# 23 SAN ANGELO TX
# 24 SHREVEPORT LA
# 25 SPRINGFIELD MO
# 26 ST JOSEPH MO
# 27 TULSA OK
# 28 TYLER-LONGVIEW TX
# 29 VICTORIA TX
# 30 WACO-TEMPLE-BRYAN TX
# media names:
# 1 tv_spend
# 2 dm_spend
# 3 paid_search_spend_brand
# 4 paid_search_spend_unbranded
# 5 display_spend
# 6 radio_spend
# 7 video_spend
# 8 print_spend
# 9 social_spend
# 10 audio_spend
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(final_data_cols)` instead of `final_data_cols` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# Adding missing grouping variables: `dma_id`, `dma`, `X`
#
# Adding missing grouping variables: `dma_id`, `dma`, `X`
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(control_names_vec)` instead of `control_names_vec` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.

# %%
# Outputs from `make_optim_data_mmm`
spend_cols_vec    = test_extraction$gross_add_true$media$spend_cols_vec
media_names_vec   = test_extraction$gross_add_true$media$media_names_vec
dma_names_vec     = test_extraction$gross_add_true$other$dma_names_vec
common_params_df  = test_extraction$gross_add_true$media$common_params_df
beta_media_mat    = test_extraction$gross_add_true$media$beta_media_mat
beta_control_mat  = test_extraction$gross_add_true$control$beta_control_mat
min_media_mat     = test_extraction$gross_add_true$media$min_media_mat
max_media_mat     = test_extraction$gross_add_true$media$max_media_mat
prospect_df       = test_extraction$gross_add_true$other$prospect_df
control_names_vec = test_extraction$gross_add_true$control$control_names_vec
control_mat       = test_extraction$gross_add_true$control$control_matrix
target_max_vec    = test_extraction$gross_add_true$target$target_max_vec
subs_col          = test_extraction$gross_add_true$other$subs_col
cleaned_names_list = test_extraction$gross_add_true$media$cleaned_media_names_vec
target_capita_norm_col = test_extraction$gross_add_true$target$target_capita_norm_col

# %%
prospect_vec = prospect_df[['non_sub']]
prospect_mat_media = matrix(prospect_vec,nrow = length(dma_names_vec), ncol = length(media_names_vec))

# %%
#*************  Simulator for Optimization  ***************************

###################################################################################################################################
#Global parameters needed for optimization
###################################################################################################################################
##Vector of Optimum DMA
optimum_dma =  c('NEW YORK, NY')
non_tv_dmas = mean_weekly_spend %>%
                mutate(dma_id = row_number(dma)) %>%
                filter(tv_spend == 0) %>%
                select(dma_id) %>%
                pull()


# media_names_vec = c('cross_channel','DM','outbound_call')


##Spend to activity ratio dataframe by DMA and media. Used primarily for activity based models for converting the activity to spend for optimization_ Dim - ndma*nmedia
spend_activity_ratio_dma_df <- as.data.frame(matrix(1, length(dma_names_vec), length(media_names_vec)))
colnames(spend_activity_ratio_dma_df) <- media_names_vec
spend_activity_ratio_dma_df[non_tv_dmas,'tv'] <- 0 

##Shape parameters used for GA calculation

K = common_params_df$K
S = common_params_df$S
alpha = common_params_df$alpha


##Spend dataframe
# data.XyZ = read.csv('MMA_final_data_with_30DMAs_v7.csv')
# data.XyZ = data.XyZ %>% 
#             #dplyr::select(-X) %>%
#             dplyr::rename(period = calendar_month, dma = DMA) %>%
#             dplyr::mutate(brand  = ifelse(dma == "NEW YORK, NY", "Optimum", "Suddenlink"),
#                           period = lubridate::as_date(period)) %>% 
#             dplyr::select(brand, dma, period, everything()) %>% 
#             dplyr::arrange(dma, period)


##Count of DMAs,medias and periods
nbr_media    = length(media_names_vec)
nbr_dma      = length(dma_names_vec)
nbr_periods  = data_XyZ %>% select(period) %>% distinct() %>% count(n()) %>% pull()
nbr_period_q = 13
n_weeks_mat = mean_n_weeks %>% rename_at(.vars = vars(spend_cols_vec), .funs = ~media_names_vec) %>% select(media_names_vec) %>% as.matrix()

target_var = 'weekly_gross_adds'
var_id_opt = which(dma_names_vec %in% optimum_dma)
# Out:
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(spend_cols_vec)` instead of `spend_cols_vec` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(media_names_vec)` instead of `media_names_vec` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.

# %%
n_weeks_mat
# Out:
#       tv        dm       paid_search_brand paid_search_unbranded display
#  [1,] 13.000000 13.00000 12.93333          12.93333              13.00000
#  [2,] 13.000000 13.00000 13.00000          13.00000              13.00000
#  [3,] 13.000000 13.00000 13.00000          13.00000              13.00000
#  [4,] 13.000000 13.00000 13.00000          12.93333              13.00000
#  [5,]  0.000000 13.00000 13.00000          13.00000              12.86667
#  [6,] 13.000000 13.00000 13.00000          13.00000              13.00000
#  [7,] 13.000000 13.00000 13.00000          13.00000              12.93333
#  [8,]  0.000000 13.00000 13.00000          13.00000              13.00000
#  [9,] 13.000000 13.00000 12.93333          12.80000              13.00000
# [10,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [11,]  0.000000 13.00000 13.00000          13.00000              13.00000
# [12,] 13.000000 13.00000 13.00000          12.86667              13.00000
# [13,] 12.266667 12.66667 13.00000          13.00000              12.93333
# [14,]  8.800000 13.00000 13.00000          12.93333              13.00000
# [15,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [16,] 12.933333 13.00000 12.93333          12.93333              13.00000
# [17,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [18,] 13.000000 13.00000 13.00000          12.93333              13.00000
# [19,]  1.733333 13.00000 13.00000          13.00000              13.00000
# [20,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [21,]  0.000000 13.00000 13.00000          13.00000              13.00000
# [22,]  0.000000 13.00000 13.00000          13.00000              13.00000
# [23,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [24,] 12.933333 13.00000 13.00000          13.00000              13.00000
# [25,] 12.200000 13.00000 13.00000          13.00000              13.00000
# [26,] 13.000000 13.00000 13.00000          12.93333              13.00000
# [27,]  1.666667 13.00000 13.00000          13.00000              12.93333
# [28,] 13.000000 13.00000 13.00000          13.00000              13.00000
# [29,] 13.000000 13.00000 13.00000          13.00000              12.93333
# [30,] 13.000000 13.00000 13.00000          13.00000              13.00000
#       radio     video    print     social   audio
#  [1,] 11.466667 12.93333 2.2666667 12.80000 4.733333
#  [2,] 11.133333 13.00000 2.5333333 12.86667 4.133333
#  [3,] 11.600000 13.00000 2.5333333 13.00000 8.200000
#  [4,] 12.400000 12.66667 4.1333333 12.93333 3.800000
#  [5,]  7.800000 12.86667 4.6666667 12.93333 5.133333
#  [6,] 11.200000 13.00000 0.8000000 13.00000 5.133333
#  [7,] 11.066667 12.93333 1.4000000 12.93333 4.666667
#  [8,]  8.533333 13.00000 4.9333333 13.00000 6.000000
#  [9,] 10.466667 12.93333 1.0000000 12.93333 4.466667
# [10,] 10.200000 13.00000 1.6666667 12.66667 4.666667
# [11,]  7.800000 13.00000 5.2000000 12.86667 5.266667
# [12,] 11.066667 12.93333 2.6000000 12.80000 4.200000
# [13,] 11.933333 12.86667 2.8666667 12.86667 3.600000
# [14,] 10.133333 13.00000 1.4666667 12.93333 4.733333
# [15,] 12.400000 13.00000 4.0000000 12.80000 4.000000
# [16,] 10.000000 12.93333 1.4666667 12.80000 4.400000
# [17,] 11.866667 13.00000 7.7333333 13.00000 9.533333
# [18,] 11.200000 12.93333 2.2000000 12.73333 4.400000
# [19,]  9.866667 13.00000 2.6666667 12.66667 4.866667
# [20,] 11.466667 12.93333 1.0000000 12.80000 4.466667
# [21,]  8.666667 13.00000 2.0666667 12.80000 5.200000
# [22,]  2.466667 13.00000 0.5333333 12.66667 5.066667
# [23,] 12.400000 12.86667 2.4000000 12.73333 4.466667
# [24,] 10.400000 12.93333 3.2666667 12.60000 4.666667
# [25,]  7.533333 12.93333 0.5333333 12.93333 5.066667
# [26,] 11.333333 12.93333 0.5333333 12.80000 4.400000
# [27,]  6.333333 12.80000 1.4000000 12.86667 4.600000
# [28,] 10.333333 13.00000 2.7333333 12.80000 4.666667
# [29,] 12.333333 12.86667 0.5333333 12.80000 4.400000
# [30,]  9.866667 13.00000 1.0666667 12.73333 4.600000

# %%
model_params = list(
'media_params' = list(
'media_names_vec' = media_names_vec,
'beta_media_mat' = beta_media_mat,
'prospect_mat_media' = prospect_mat_media,
'K' = K,
'S' = S,
'alpha' = alpha,
'max_media_mat' = max_media_mat,
'min_media_mat' = min_media_mat,
'cleaned_names_list' = cleaned_names_list,
'spend_activity_ratio_dma_df' = spend_activity_ratio_dma_df,
'spend_cols_vec' = spend_cols_vec,
'n_weeks_mat' = n_weeks_mat
),
'control_params' = list(
'control_mat' = control_mat,
'control_names_vec' = control_names_vec,
'beta_control_mat' = beta_control_mat
),
'target_params' = list(
'target_var' = target_var,
'target_max_vec' = target_max_vec,
'target_capita_norm_col' = target_capita_norm_col
),    
'other_params' = list(
'nbr_period_q' = nbr_period_q,
'dma_names_vec' = dma_names_vec,
'optimum_dma' = optimum_dma
)
)

# %%
n_media = length(media_names_vec)
n_geo = length(dma_names_vec)
n_control = length(control_names_vec)

# %%
var_media = model_params$media_params$spend_cols_vec
var_media
# Out:
#  [1] "tv_spend"                    "dm_spend"
#  [3] "paid_search_spend_brand"     "paid_search_spend_unbranded"
#  [5] "display_spend"               "radio_spend"
#  [7] "video_spend"                 "print_spend"
#  [9] "social_spend"                "audio_spend"

# %%
fit_metrics_mean_df <- fit_metrics_df %>%
                        mutate(group = toupper(group),
                               metric = toupper(metric)) %>%
                        filter(metric %in% c('R2','MAPE') & sample_type == 'Train') %>%
                        select(dma = group,metric,Mean) %>%
                        spread(metric,Mean)

fit_metrics_mean_df
# Out:
#    dma                            MAPE      R2
# 1  ABILENE-SWEETWATER TX           9.695906 0.6083036
# 2  ALEXANDRIA LA                  18.669054 0.6115114
# 3  ALL OTHER SUDDENLINK DMA TOTAL  9.803658 0.4148412
# 4  ALTICE                          4.788842 0.8040647
# 5  AMARILLO TX                     8.028108 0.6454911
# 6  AUSTIN TX                       9.397962 0.8242219
# 7  BLUEFIELD-BECKLEY-OAK HILL WV  10.083701 0.5877866
# 8  CHARLESTON-HUNTINGTON WV        8.498242 0.5355688
# 9  DALLAS-FT WORTH TX              8.713493 0.7867151
# 10 EUREKA CA                      11.553650 0.7064645
# 11 GREENVILLE-NEW BERN-WASH NC    10.161076 0.7325105
# 12 HOUSTON TX                      8.198177 0.7712350
# 13 JONESBORO AR                   10.286455 0.7299435
# 14 LAKE CHARLES LA                31.382752 0.5619427
# 15 LITTLE ROCK AR                  9.701155 0.5724813
# 16 LUBBOCK TX                      9.595767 0.7959151
# 17 MONROE-EL DORADO LA-AR         15.763378 0.6434788
# 18 NEW YORK, NY                    6.837176 0.6704553
# 19 ODESSA-MIDLAND TX               9.309892 0.5384719
# 20 OKLAHOMA CITY OK                9.993396 0.8493060
# 21 OPTIMUM                         6.837176 0.6704553
# 22 PARKERSBURG WV                 13.590261 0.5932271
# 23 PHOENIX AZ                      7.367773 0.6824236
# 24 RALEIGH-DURHAM NC              14.212661 0.5387189
# 25 SAN ANGELO TX                  11.368753 0.5437986
# 26 SHREVEPORT LA                  10.345367 0.7127148
# 27 SPRINGFIELD MO                  8.590616 0.5837844
# 28 ST JOSEPH MO                   11.571784 0.5811136
# 29 SUDDENLINK                      5.293613 0.8430018
# 30 TULSA OK                       11.447602 0.5252434
# 31 TYLER-LONGVIEW TX               8.756116 0.8109298
# 32 VICTORIA TX                    12.119089 0.5742436
# 33 WACO-TEMPLE-BRYAN TX           16.855119 0.8008620

# %% [markdown]
# ### Computing using the mean of all parameters

# %%
res <- compute_elasticity_and_contribution(model_params = model_params,
                                              mean_qy_spend = mean_qy_spend,
                                            mean_weekly_spend = mean_weekly_spend,
                                           activity_based_media = NULL,
                                           data_XyZ = data_XyZ,
                                             spend_change = c(0.1,0.3))
# Out:
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.
#
# Adding missing grouping variables: `qy`
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(control_names)` instead of `control_names` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.
#
# Adding missing grouping variables: `qy`
#
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.
#
# Adding missing grouping variables: `qy`
#
# `summarise()` has grouped output by 'dma'. You can override using the `.groups` argument.
#
# Adding missing grouping variables: `qy`
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(display_order)` instead of `display_order` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(var_Elasticity_up)` instead of `var_Elasticity_up` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
#
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(var_Elasticity_down)` instead of `var_Elasticity_down` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
# Order of media:
# 1.tv
# 2.dm
# 3.paid_search_brand
# 4.paid_search_unbranded
# 5.display
# 6.radio
# 7.video
# 8.print
# 9.social
# 10.audio
# 11.total

# %%
res$Elasticity$`Elasticity_up_0.1`
# Out:
# [[1]]
# # A tibble: 33 × 12
#    dma            tv    dm paid_search_bra… paid_search_unb… display radio video
#    <fct>       <dbl> <dbl>            <dbl>            <dbl>   <dbl> <dbl> <dbl>
#  1 ALTICE       0.24  0.09             0.78             0.05    0.04  0.02  0.02
#  2 SUDDENLINK   0.19  0.06             0.99             0.06    0.03  0.03  0.01
#  3 OPTIMUM      0.29  0.11             0.65             0.04    0.04  0     0.03
#  4 ABILENE-S…   0.15  0.04             1.17             0.02    0     0     0
#  5 ALEXANDRI…   0.21  0.05             0.46             0.01    0     0     0
#  6 All Other…   0.34  0.07             0.67             0.15    0.1   0.02  0.04
#  7 AMARILLO …   0.18  0.05             0.95             0.01    0     0     0
#  8 AUSTIN TX  NaN     0.06             0.85             0.13    0.06  0.09  0.02
#  9 BLUEFIELD…   0.21  0.04             0.74             0.01    0     0.01  0
# 10 CHARLESTO…   0.17  0.02             0.44             0.01    0.01  0     0
# # … with 23 more rows, and 4 more variables: print <dbl>, social <dbl>,
# #   audio <dbl>, spend_media_total <dbl>

# %%
res$All_metrics_detailed
# Out:
#     dma                  media                 mean_spend Media_GA
# 1   ALTICE               tv                    12815856   
0.00              0.00
# ⋮   ⋮                 ⋮          ⋮                 ⋮
# 367   0.1187360205    5942       0.00              0.00
# 368   0.4322905302    5942       0.03              0.03
# 369   0.4953797930    5942       0.01              0.01
# 370   0.0011966052    5942       0.00              0.00
# 371 356.4384120549    5942       0.14              0.14
# 372 356.4384120549    5942       0.14              0.14
# 373 103.2923947840    1014       0.00              0.01
# 374   1.9743605005    1014       0.13              0.10
# 375  34.1113400900    1014       1.31              1.27
# 376   0.2135221331    1014       0.03              0.02
# 377   0.0310938640    1014       0.01              0.01
# 378   0.5693106560    1014       0.06              0.05
# 379   0.0141017484    1014       0.01              0.00
# 380   0.0750142828    1014       0.15              0.13
# 381   0.0761515443    1014       0.02              0.02
# 382   0.0002095868    1014       0.00              0.00
# 383 140.3574991898    1014       0.10              0.10
# 384 140.3574991898    1014       0.10              0.10
# 385 126.8636088426    3931       0.14              0.14
# 386   2.9941881045    3931       0.04              0.03
# 387 255.2541467468    3931       1.79              1.73
# 388   0.7776305426    3931       0.02              0.01
# 389   0.3497124995    3931       0.01              0.01
# 390   0.0377201405    3931       0.00              0.00
# 391   0.0616675682    3931       0.00              0.00
# 392   0.0960915950    3931       0.03              0.02
# 393   0.1910763048    3931       0.01              0.01
# 394   0.0008501621    3931       0.00              0.00
# 395 386.6266925066    3931       0.20              0.20
# 396 386.6266925066    3931       0.20              0.20
#     Elasticity_up_0.3 Elasticity_down_0.3
# 1   0.23              0.25
# 2   0.11              0.06
# 3   0.80              0.72
# 4   0.06              0.03
# 5   0.04              0.02
# 6   0.03              0.01
# 7   0.02              0.01
# 8   0.05              0.03
# 9   0.02              0.01
# 10  0.00              0.00
# 11  0.18              0.16
# 12  0.18              0.16
# 13  0.18              0.19
# 14  0.07              0.04
# 15  1.02              0.91
# 16  0.07              0.04
# 17  0.04              0.02
# 18  0.04              0.02
# 19  0.01              0.01
# 20  0.06              0.04
# 21  0.01              0.01
# 22  0.01              0.00
# 23  0.16              0.13
# 24  0.16              0.13
# 25  0.28              0.31
# 26  0.14              0.07
# 27  0.66              0.61
# 28  0.04              0.02
# 29  0.05              0.03
# 30  0.00              0.00
# ⋮   ⋮                 ⋮
# 367 0.01              0.00
# 368 0.04              0.02
# 369 0.02              0.01
# 370 0.00              0.00
# 371 0.15              0.13
# 372 0.15              0.13
# 373 0.00              0.12
# 374 0.16              0.08
# 375 1.34              1.22
# 376 0.04              0.02
# 377 0.01              0.01
# 378 0.07              0.04
# 379 0.01              0.00
# 380 0.17              0.11
# 381 0.02              0.01
# 382 0.00              0.00
# 383 0.10              0.15
# 384 0.10              0.15
# 385 0.14              0.14
# 386 0.05              0.02
# 387 1.85              1.65
# 388 0.02              0.01
# 389 0.01              0.01
# 390 0.00              0.00
# 391 0.00              0.00
# 392 0.03              0.02
# 393 0.01              0.01
# 394 0.00              0.00
# 395 0.21              0.19
# 396 0.21              0.19

# %%
mean_metrics_df <- res$All_metrics_detailed %>%
                   left_join(fit_metrics_mean_df)
mean_metrics_df
# Out:
# Joining, by = "dma"
#     dma                  media                 mean_spend Media_GA
# 1   ALTICE               tv                    12815856   14840.7213151
# 2   ALTICE               dm                     8281353    1039.2773074
# 3   ALTICE               paid_search_brand      3428487    9686.3249824
# 4   ALTICE               paid_search_unbranded  4672666     349.5084467
# 5   ALTICE               display                4229179     225.7449063
# 6   ALTICE               radio                  2010964      65.5544871
# 7   ALTICE               video                  2557005      77.5792527
# 8   ALTICE               print                   363018      31.7466129
# 9   ALTICE               social                 1568001      50.8713448
# 10  ALTICE               audio                   130178       1.1452918
# 11  ALTICE               spend_media_total     40056706   26368.4739471
# 12  ALTICE               Total                 40056706   26368.4739471
# 13  SUDDENLINK           tv                     3273368    3478.0749429
# 14  SUDDENLINK           dm                     3411115     367.9119149
# 15  SUDDENLINK           paid_search_brand      1124392    4985.0723774
# 16  SUDDENLINK           paid_search_unbranded  2242182     238.6110446
# 17  SUDDENLINK           display                1551388      85.5167343
# 18  SUDDENLINK           radio                  1046863      61.3385932
# 19  SUDDENLINK           video                   861778      20.0652781
# 20  SUDDENLINK           print                   233276      30.9629832
# 21  SUDDENLINK           social                  615347      17.3267378
# 22  SUDDENLINK           audio                    42668       0.6658356
# 23  SUDDENLINK           spend_media_total     14402378    9285.5464420
# 24  SUDDENLINK           Total                 14402378    9285.5464420
# 25  OPTIMUM              tv                     9542488   11362.6463722
# 26  OPTIMUM              dm                     4870238     671.3653925
# 27  OPTIMUM              paid_search_brand      2304095    4701.2526050
# 28  OPTIMUM              paid_search_unbranded  2430484     110.8974021
# 29  OPTIMUM              display                2677791     140.2281720
# 30  OPTIMUM              radio                   964101       4.2158939
# ⋮   ⋮                    ⋮                     ⋮          ⋮
# 367 TYLER-LONGVIEW TX    video                  36007       0.3591003519
# 368 TYLER-LONGVIEW TX    print                  10656       1.0786138831
# 369 TYLER-LONGVIEW TX    social                 36282       1.3299414800
# 370 TYLER-LONGVIEW TX    audio                   1020       0.0028540577
# 371 TYLER-LONGVIEW TX    spend_media_total     802903     611.7204389736
# 372 TYLER-LONGVIEW TX    Total                 802903     611.7204389736
# 373 VICTORIA TX          tv                    124494     126.8969850700
# 374 VICTORIA TX          dm                     33590       6.4136384119
# 375 VICTORIA TX          paid_search_brand      11924      57.3299145325
# 376 VICTORIA TX          paid_search_unbranded  14618       0.6707855168
# 377 VICTORIA TX          display                 8139       0.0981588051
# 378 VICTORIA TX          radio                  21777       1.8514273291
# 379 VICTORIA TX          video                   5100       0.0426500993
# 380 VICTORIA TX          print                    638       0.1858281431
# 381 VICTORIA TX          social                  5645       0.2044444513
# 382 VICTORIA TX          audio                    163       0.0004998913
# 383 VICTORIA TX          spend_media_total     226089     193.6943322503
# 384 VICTORIA TX          Total                 226089     193.6943322503
# 385 WACO-TEMPLE-BRYAN TX tv                    173139     199.5210305813
# 386 WACO-TEMPLE-BRYAN TX dm                     96090       9.8326358156
# 387 WACO-TEMPLE-BRYAN TX paid_search_brand      36402     432.6474498288
# 3   0.80              0.72                4.788842  0.8040647
# 4   0.06              0.03                4.788842  0.8040647
# 5   0.04              0.02                4.788842  0.8040647
# 6   0.03              0.01                4.788842  0.8040647
# 7   0.02              0.01                4.788842  0.8040647
# 8   0.05              0.03                4.788842  0.8040647
# 9   0.02              0.01                4.788842  0.8040647
# 10  0.00              0.00                4.788842  0.8040647
# 11  0.18              0.16                4.788842  0.8040647
# 12  0.18              0.16                4.788842  0.8040647
# 13  0.18              0.19                5.293613  0.8430018
# 14  0.07              0.04                5.293613  0.8430018
# 15  1.02              0.91                5.293613  0.8430018
# 16  0.07              0.04                5.293613  0.8430018
# 17  0.04              0.02                5.293613  0.8430018
# 18  0.04              0.02                5.293613  0.8430018
# 19  0.01              0.01                5.293613  0.8430018
# 20  0.06              0.04                5.293613  0.8430018
# 21  0.01              0.01                5.293613  0.8430018
# 22  0.01              0.00                5.293613  0.8430018
# 23  0.16              0.13                5.293613  0.8430018
# 24  0.16              0.13                5.293613  0.8430018
# 25  0.28              0.31                6.837176  0.6704553
# 26  0.14              0.07                6.837176  0.6704553
# 27  0.66              0.61                6.837176  0.6704553
# 28  0.04              0.02                6.837176  0.6704553
# 29  0.05              0.03                6.837176  0.6704553
# 30  0.00              0.00                6.837176  0.6704553
# ⋮   ⋮                 ⋮                   ⋮         ⋮
# 367 0.01              0.00                 8.756116 0.8109298
# 368 0.04              0.02                 8.756116 0.8109298
# 369 0.02              0.01                 8.756116 0.8109298
# 370 0.00              0.00                 8.756116 0.8109298
# 371 0.15              0.13                 8.756116 0.8109298
# 372 0.15              0.13                 8.756116 0.8109298
# 373 0.00              0.12                12.119089 0.5742436
# 374 0.16              0.08                12.119089 0.5742436
# 375 1.34              1.22                12.119089 0.5742436
# 376 0.04              0.02                12.119089 0.5742436
# 377 0.01              0.01                12.119089 0.5742436
# 378 0.07              0.04                12.119089 0.5742436
# 379 0.01              0.00                12.119089 0.5742436
# 380 0.17              0.11                12.119089 0.5742436
# 381 0.02              0.01                12.119089 0.5742436
# 382 0.00              0.00                12.119089 0.5742436
# 383 0.10              0.15                12.119089 0.5742436
# 384 0.10              0.15                12.119089 0.5742436
# 385 0.14              0.14                16.855119 0.8008620
# 386 0.05              0.02                16.855119 0.8008620
# 387 1.85              1.65                16.855119 0.8008620
# 388 0.02              0.01                16.855119 0.8008620
# 389 0.01              0.01                16.855119 0.8008620
# 390 0.00              0.00                16.855119 0.8008620
# 391 0.00              0.00                16.855119 0.8008620
# 392 0.03              0.02                16.855119 0.8008620
# 393 0.01              0.01                16.855119 0.8008620
# 394 0.00              0.00                16.855119 0.8008620
# 395 0.21              0.19                16.855119 0.8008620
# 396 0.21              0.19                16.855119 0.8008620

# %%
using_mean_plts <- gen_contrib_elas_plots(mean_metrics_df,activity_based_media,'Elasticity_up_0.1')

# %%
options(repr.plot.width=8, repr.plot.height = 8)
using_mean_plts$brand_plots$ALTICE
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height = 8)
using_mean_plts$brand_plots$SUDDENLINK
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height = 8)
using_mean_plts$brand_plots$OPTIMUM
# Out:
# plot without title

# %%
save(model_params,file = 'model_params/model_params_PP_44_10_C19_beta_res_xy995.rda')
